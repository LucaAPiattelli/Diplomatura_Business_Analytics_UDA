# %% [markdown]
# <a href="https://colab.research.google.com/github/LucaAPiattelli/Diplomatura_Business_Analytics_UDA/blob/main/Modulo_04_Estadistica/EjercicioN16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
#
# ![index.png](data:image/png;base64,...)
#
# <center/>

# %% [markdown]
# <center>
# <font color="#41a8c7">
# <h2><b>
# Serie de tiempo-Series estacional-Ruido Blanco
# </font>
# </center>

# %% [markdown]
# **Ejercicio Nº16** Generar un ruido blanco usando una distribución normal

# %% [markdown]
# 1.Con una media de 0 y desviación de 1. Usar 100 periodos

# %%
#--------------------------------------------------------------------
 tiempo=c(1:100) 

  
  x=NULL
  
  t=1
  
  while(t<=100){
    
  x[t]= rnorm(1,0,1) 
    
    
  t=t+1  
  }

# %% [markdown]
# 2.Graficar la serie de tiempo

# %%
 #-----------------------------------------------------------------------  
  
  plot(x, ylab="Xt", xlab="Tiempo" ,type="o",lwd=1,pch=1,cex=1,col="Green")
  abline(h=0)
# Out:
# plot without title
