# %% [markdown]
# <a href="https://colab.research.google.com/github/LucaAPiattelli/Diplomatura_Business_Analytics_UDA/blob/main/Modulo_04_Estadistica/EjercicioN7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# ![index.png](data:image/png;base64,...)
#
# <center/>

# %% [markdown]
# <center>
# <font color="#41a8c7">
# <h2><b>
# Variable aleatoria-Distribución exponencial
# </font>
# </center>

# %% [markdown]
# **Ejercicio Nº7:** La variable aleatoria X representa el tiempo de carga para un camión en el muelle de Buenos Aires  y sigue dicha distribución exponencial.  Si la media, o promedio, del tiempo de carga es 15 minutos. Calcule:

# %% [markdown]
# 1.La probabilidad de que el camión se descargue en menos de 6 minutos

# %%
pexp(6,1/15)
# Out:
# [1] 0.32968

# %% [markdown]
# 2.La probabilidad de que se descargue entre 16 y 18 minutos

# %%
pexp(18,1/15)-pexp(16,1/15)
# Out:
# [1] 0.04295957

# %% [markdown]
# Gráficar la función de densidad sobre el histograma

# %%
muestra=rexp(1000,1/15)

h=hist(muestra,probability = T,breaks=100)

curve(dexp(x,1/15), 
       col="darkblue", lwd=2,
       add=TRUE, yaxt="n")
# Out:
# Plot with title “Histogram of muestra”

# %%
help(dexp)
