# %% [markdown]
# <a href="https://colab.research.google.com/github/LucaAPiattelli/Diplomatura_Business_Analytics_UDA/blob/main/Modulo_04_Estadistica/EjercicioN19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# ![index.png](data:image/png;base64,...)
#
# <center/>

# %% [markdown]
# <center>
# <font color="#41a8c7">
# <h2><b>
# Serie de tiempo-Series estacional-ARMA
# </font>
# </center>

# %% [markdown]
# **Ejercicio Nº19** Generar un ARMA(1,1) usando una distribución normal, con media 0 y desviación 1

# %% [markdown]
# Instalar librería

# %%
install.packages("forecast")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘TTR’, ‘quadprog’, ‘quantmod’, ‘fracdiff’, ‘lmtest’, ‘timeDate’, ‘tseries’, ‘urca’, ‘zoo’, ‘RcppArmadillo’

# %% [markdown]
# Cargar librería

# %%
    library(forecast)
# Out:
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %% [markdown]
# 1.Usar 0,6 para ambos parámeteros

# %%
tiempo=c(1:100)

x=rnorm(1,0,1)
e=rnorm(1,0,1)

t=2

while(t<=100){
  
  e[t]=rnorm(1,0,1) 
  x[t]=0.6*x[t-1]+0.6*e[t-1]+e[t]
  
  
  t=t+1  
}

# %% [markdown]
# 2.Gráficar

# %%
  plot(x, ylab="Xt", xlab="Tiempo" ,type="o",lwd=1,pch=1,cex=1,col="Green")
  abline(h=0)
# Out:
# plot without title

# %% [markdown]
# 3.Estimar el modelo

# %%
  
  fit=auto.arima(x,seasonal = F,ic = c("aicc"), stepwise=T, allowdrift = F)
  summary(fit)
# Out:
# Series: x
# ARIMA(1,0,1) with zero mean
#
# Coefficients:
#          ar1     ma1
#       0.6811  0.6849
# s.e.  0.0777  0.0800
#
# sigma^2 estimated as 1.002:  log likelihood=-141.99
# AIC=289.98   AICc=290.23   BIC=297.8
#
# Training set error measures:
#                      ME      RMSE       MAE      MPE     MAPE      MASE
# Training set -0.0806556 0.9909115 0.8242364 129.7935 409.1407 0.8519665
#                     ACF1
# Training set -0.00303635
