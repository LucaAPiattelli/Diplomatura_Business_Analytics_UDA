# %% [markdown]
# # Diplomatura en **Business Analytics** - FCEJ/UdA - **Estadística inferencial**
#
# ***Modelo lineal/simple***
#
# ![Logo diplo.png](data:image/png;base64,...)

# %% [markdown]
# **Ejercicio nº12:** El dueño de una pyme mendocina, está preocupado por la disminución en la cantidad de afiliados en los últimos años, a pesar de que se ha aumentado la intensidad en la comercialización y también en la calidad del servicio. Una posibilidad es que esta disminución sea por motivos económicos externos a la pyme. Una hipótesis es que sea por la disminución generalizada del ingreso es decir el PBI per cápita. En la muestra se mide la  cantidad de  afiliados, desde el 2005 (inicio actividad) hasta el 2020. La medición se hace en diciembre. Por otro lado se toma una muestra del PBI per cápita en el mismo período,en dólares corrientes:

# %%
#-----------------------------------------------------------------------
#Instalar Librerias
#----------------------------------------------------------------------

install.packages("lmtest")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘zoo’

# %%
#-----------------------------------------------------------------------
#Librerias
#----------------------------------------------------------------------
#Libreria grafica
library(ggplot2)
#Libreria test B-P
library(lmtest)
# Out:
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric

# %% [markdown]
# 1.Grafique la cantidad de afiliados y PBI per cápita  en función del tiempo

# %%
#--------------------------------------------------------------------------
#Cargar Datos
pbi_pc=c(5110,5919,7245,9021,8225,10386,12849,13083,13080,12335,13789,12790,14613,11633,9912,8938)
          

afiliados=c(120,50,70,130,60,60,150,150,90,170,220,160,150,60,50,60)


tiempo=c(2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020)

# %%
plot(tiempo,afiliados,type = "o")

plot(tiempo,pbi_pc,type = "o")
# Out:
# plot without title
# plot without title

# %% [markdown]
# 2.Grafique cantidad de afiliados vs PBI per cápita

# %%
#--------------------------------------------------------------------------
#Graficar

g=ggplot(data.frame(pbi_pc=pbi_pc,afiliados=afiliados),aes(x=pbi_pc,y=afiliados))
g=g+geom_smooth(method=lm,formula = y ~ poly(x, 1))
g=g+geom_point(shape=1)
g
# Out:
# plot without title

# %% [markdown]
# 3.Estimar el modelo lineal

# %%
#-------------------------------------------------------------------------
#Modelo lineal

modelo_lineal=lm(afiliados~pbi_pc)

summary(modelo_lineal)
# Out:
# Call:
# lm(formula = afiliados ~ pbi_pc)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -61.162 -35.466  -3.443  28.983  75.197
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -6.394100  42.861719  -0.149   0.8835
# pbi_pc       0.010965   0.003922   2.796   0.0143 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 44.24 on 14 degrees of freedom
# Multiple R-squared:  0.3583,	Adjusted R-squared:  0.3124
# F-statistic: 7.816 on 1 and 14 DF,  p-value: 0.0143

# %% [markdown]
# 4.Cuanto de la variación de afiliados es explicado por el PBI per cápita

# %%
#35%

# %% [markdown]
# 5.Qué puede concluir usando la prueba t y la prueba F

# %%
#Es significativo

# %% [markdown]
# 6.Analizar los supuestos del modelo

# %%
#---------------------------------------------------------------------------
#Analisis supuestos
#---------------------------------------------------------------------------
#Test de shapiro-Wilks
#---------------------------------------------------------------------------

#H0: Es normal    vs    H1: no es normal

shapiro.test(rstandard(modelo_lineal))

hist(modelo_lineal$residuals)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  rstandard(modelo_lineal)
# W = 0.94745, p-value = 0.4505
# Plot with title “Histogram of modelo_lineal$residuals”

# %%
#-----------------------------------------------------------------------------------
#test Breusch-Pagan test
#----------------------------------------------------------------------------------

#H0: todas las varianzas son iguales vs H1: al menos una es diferente

bptest(modelo_lineal)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  modelo_lineal
# BP = 0.0035184, df = 1, p-value = 0.9527

# %%
#--------------------------------------------------------------------------------------
#Durbin-Watson
#--------------------------------------------------------------------------------------
#H0: errores son independientes  vs H1: no son independientes

dwtest(modelo_lineal)
# Out:
# 	Durbin-Watson test
#
# data:  modelo_lineal
# DW = 1.307, p-value = 0.04065
# alternative hypothesis: true autocorrelation is greater than 0

# %% [markdown]
# 7.Estime cuánto sería la cantidad de afiliados si el  PBI per cápita fuera de 11000 dólares

# %%
#----------------------------------------------------------------------------------------

0.010965*11000
# Out:
# [1] 120.615
