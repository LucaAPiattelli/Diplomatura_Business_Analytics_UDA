# %% [markdown]
# # Diplomatura en **Business Analytics** - FCEJ/UdA - **Serie de tiempo**
#
# ***Serie estacional/Modelo SARIMA***
#
# ![Logo diplo.png](data:image/png;base64,...)

# %% [markdown]
# **Ejercicio Nº22 **Generar una proceso SARIMA(0,0,0)(0,1,0) usando una distribución normal, con media 0 y desviación 1

# %%
#-------------------------------------------------------------------------------
#Instalar librerias
#-------------------------------------------------------------------------------

install.packages("forecast")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘TTR’, ‘quadprog’, ‘quantmod’, ‘fracdiff’, ‘lmtest’, ‘timeDate’, ‘tseries’, ‘urca’, ‘zoo’, ‘RcppArmadillo’

# %%
#-----------------------------------------------------------------------------------------
#Cargar librerias
#----------------------------------------------------------------------------------------

library(forecast)
# Out:
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %% [markdown]
# 1.Cada 12 meses sumar 5, a la serie

# %%
#--------------------------------------------------------------------

tiempo=c(1:(12*10))

x=rnorm(1,0,1)


t=1

while(t<=120){
  
  
  x[t]=rnorm(1,0,1)
  
  
  t=t+1  
}

# %%
plot(x, ylab="Xt", xlab="Tiempo" ,type="o",lwd=1,pch=1,cex=1,col="Green")
abline(h=0)
# Out:
# plot without title

# %%
#Sumar estacionalidad


i=1

while(i<=10){
  
  
  x[12*i]=5
  
  
  i=i+1  
}

# %% [markdown]
# 2.Gráficar

# %%
#-----------------------------------------------------------------------


plot(x, ylab="Xt", xlab="Tiempo" ,type="o",lwd=1,pch=1,cex=1,col="Green")
abline(h=0)
# Out:
# plot without title

# %% [markdown]
# 3.Estimar el modelo

# %%
#------------------------------------------------------------------------
#Crear datos ts
x = ts(x,frequency = 12)

# %%
#------------------------------------------------------------------------
fit=auto.arima(x,seasonal = T,ic = c("aicc"), stepwise=T, allowdrift = F)
summary(fit)
# Out:
# Series: x
# ARIMA(0,0,0)(0,1,1)[12]
#
# Coefficients:
#          sma1
#       -0.6987
# s.e.   0.0985
#
# sigma^2 estimated as 0.9853:  log likelihood=-155.96
# AIC=315.92   AICc=316.03   BIC=321.28
#
# Training set error measures:
#                       ME      RMSE       MAE      MPE     MAPE      MASE
# Training set -0.03084495 0.9373348 0.6870121 169.1359 226.0127 0.7178833
#                     ACF1
# Training set -0.06874803
