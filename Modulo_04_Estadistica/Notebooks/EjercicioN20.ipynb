# %% [markdown]
# # Diplomatura en **Business Analytics** - FCEJ/UdA - **Serie de tiempo**
#
# ***Serie estacional/Modelo ARIMA***
#
# ![Logo diplo.png](data:image/png;base64,...)

# %% [markdown]
# **Ejercicio Nº20** Generar una proceso con tendencia determinística usando una distribución normal, con media 0 y desviación 1

# %%
#-------------------------------------------------------------------------------
#Instalar librerias
#-------------------------------------------------------------------------------

install.packages("forecast")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘TTR’, ‘quadprog’, ‘quantmod’, ‘fracdiff’, ‘lmtest’, ‘timeDate’, ‘tseries’, ‘urca’, ‘zoo’, ‘RcppArmadillo’

# %%
  
  #-----------------------------------------------------------------------------------------
  #Cargar librerias
  #----------------------------------------------------------------------------------------
  
  library(forecast)
# Out:
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %% [markdown]
# 1.Usar  y  ordenada al origen 0,1 y pendiente 0,1

# %%
#--------------------------------------------------------------------

tiempo=c(1:100)

x=rnorm(1,0,1)


t=1

while(t<=100){
  
  
  x[t]=0.1+0.1*tiempo[t]+rnorm(1,0,1)
  
  
  t=t+1  
}

# %% [markdown]
# 2.Gráficar

# %%
plot(x, ylab="Xt", xlab="Tiempo" ,type="o",lwd=1,pch=1,cex=1,col="Green")
abline(h=0)
# Out:
# plot without title

# %% [markdown]
# 3.Estimar el modelo

# %%
fit=auto.arima(x,seasonal = F,ic = c("aicc"), stepwise=T, allowdrift = T)
summary(fit)
# Out:
# Series: x
# ARIMA(0,1,1) with drift
#
# Coefficients:
#           ma1   drift
#       -0.9043  0.1017
# s.e.   0.0574  0.0107
#
# sigma^2 estimated as 0.9852:  log likelihood=-139.58
# AIC=285.16   AICc=285.41   BIC=292.94
#
# Training set error measures:
#                      ME      RMSE       MAE      MPE     MAPE      MASE
# Training set 0.01561077 0.9775711 0.7616751 8.789056 28.30429 0.7058524
#                   ACF1
# Training set 0.0442876

# %%
dx=diff(x,1)


plot(dx, ylab="dXt", xlab="Tiempo" ,type="o",lwd=1,pch=1,cex=1,col="Green")
abline(h=0)
# Out:
# plot without title

# %%
#-----------------------------------------------------------------------

fit=auto.arima(dx,seasonal = F,ic = c("aicc"), stepwise=T, allowdrift = F)
summary(fit)
# Out:
# Series: dx
# ARIMA(0,0,1) with non-zero mean
#
# Coefficients:
#           ma1    mean
#       -0.9043  0.1017
# s.e.   0.0574  0.0107
#
# sigma^2 estimated as 0.9852:  log likelihood=-139.58
# AIC=285.16   AICc=285.41   BIC=292.94
#
# Training set error measures:
#                      ME      RMSE       MAE      MPE     MAPE      MASE
# Training set 0.01577212 0.9824959 0.7693651 2098.661 2207.558 0.4117815
#                    ACF1
# Training set 0.04420866
