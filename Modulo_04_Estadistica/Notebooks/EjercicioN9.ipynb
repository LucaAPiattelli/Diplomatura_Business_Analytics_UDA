# %% [markdown]
# # Diplomatura en **Business Analytics** - FCEJ/UdA - **Estadística inferencial**
#
# ***Estimación puntual/intervalo***

# %% [markdown]
# **Ejercicio Nº9**.  Una empresa que otorga créditos,en Neuquén, quiere estimar la media de lo adeudado por las tarjetas de crédito que esta otorga a sus clientes. Para ello se tomó una muestra aleatoria de 35 familias. Suponiendo que la población tiene varianza finita, estime:

# %% [markdown]
# 1.El el valor observado del estimador puntual para la media poblacional

# %%
muestra=c(13461,15548,15223,16374,15780,12918,14297,15651,16344,15133,14949,14042,14434,
          14554,16258,15302,15360,14902, 12511,16611, 15228,16370,16424, 13570,15132,16676,
          14694, 14741,14287,15182,14311, 13724, 15615,16092,15013)

# %%
#M
mean(muestra)
# Out:
# [1] 15048.89

# %% [markdown]
# 2.Un intervalo de confianza del 95%, para la media poblacional
